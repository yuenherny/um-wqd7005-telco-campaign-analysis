# %%
import pandas as pd

# %%
df = pd.read_csv("midterm_dataset.csv")
df
# Out:
#      TENURE  AGE  GENDER NATIONALITY         STATE STATUS_BEFORE STATUS_AFTER  \
# 0       133   33    Male    Malaysia  KLANG VALLEY        Active       Active
# 1        37   41    Male    Malaysia       SARAWAK        Active       Active
# 2        44   21    Male    Malaysia       SARAWAK        Active       Active
# 3       176   69  Female    Malaysia        PENANG        Active       Active
# 4       171   79    Male    Malaysia        JOHORE        Active       Active
# ..      ...  ...     ...         ...           ...           ...          ...
# 722      65   35    Male    Malaysia  KLANG VALLEY        Active       Active
# 723     149   29  Female    Malaysia  KLANG VALLEY        Active       Active
# 724     126   39    Male    Malaysia       SARAWAK        Active       Active
# 725      62   23    Male    Malaysia    TERENGGANU        Active       Active
# 726      29   61    Male    Malaysia       SARAWAK        Active       Active
#
# ...

# %%
import random

df_index = random.sample(range(len(df)), round(len(df) * .025))[:15]
df_index
# Out:
# [437, 172, 286, 236, 479, 421, 180, 413, 676, 206, 317, 177, 88, 197, 671]

# %%
df = df[["GENDER", "PLAN_TYPE", "OFFER_TAKER"]]
df = df.loc[df_index]
df
# Out:
#      GENDER PLAN_TYPE OFFER_TAKER
# 437  Female     Saver           Y
# 172  Female   Premium           Y
# 286  Female     Saver           Y
# 236    Male     Saver           Y
# 479    Male     Saver           N
# 421  Female   Premium           N
# 180  Female     Saver           Y
# 413  Female   Premium           N
# 676    Male     Saver           Y
# 206    Male   Premium           Y
# 317    Male   Premium           Y
# 177  Female   Premium           Y
# 88     Male   Premium           N
# 197    Male   Premium           Y
# 671    Male   Premium           Y

# %%
df.to_csv("decision_tree_dataset.csv")
