# %%
import os
import pandas as pd

# %%
DATASET_PATH = "dataset"

# %%
df = pd.read_csv(os.path.join(DATASET_PATH, "7k dataset.txt"))
df
# Out:
#       TENURE  AGE  GENDER NATIONALITY         STATE STATUS_BEFORE  \
# 0        133   33    Male    Malaysia  KLANG VALLEY        Active
# 1         37   41    Male    Malaysia       SARAWAK        Active
# 2         44   21    Male    Malaysia       SARAWAK        Active
# 3        176   69  Female    Malaysia        PENANG        Active
# 4        171   79    Male    Malaysia        JOHORE        Active
# ...      ...  ...     ...         ...           ...           ...
# 7267      28   27    Male    Malaysia  KLANG VALLEY        Active
# 7268      48   25    Male    Malaysia  KLANG VALLEY        Active
# 7269      71   65    Male    Malaysia        PAHANG        Active
# 7270      30   33    Male    Malaysia        JOHORE        Active
# 7271      16   36  Female    Malaysia  KLANG VALLEY        Active
#
#      STATUS_AFTER OFFER_TAKER OFFER_TAKE_UP_DT DATA_PURC_BEFORE  ...  \
# 0          Active           Y        10/6/2022                Y  ...
# 1          Active           Y        10/6/2022                Y  ...
# 2          Active           N                ?                N  ...
# 3          Active           N                ?                N  ...
# 4          Active           Y        10/6/2022                N  ...
# ...           ...         ...              ...              ...  ...
# 7267       Active           Y        10/6/2022                Y  ...
# 7268       Active           Y        10/8/2022                Y  ...
# 7269       Active           Y        10/6/2022                Y  ...
# 7270       Active           N                ?                N  ...
# 7271       Active           Y        10/6/2022                Y  ...
#
#      RLD_IND_BEFORE RLD_IND_AFTER RLD_AMT_BEFORE  RLD_AMT_AFTER  \
# 0                 Y             Y          30.00          30.00
# 1                 N             N              ?              ?
# 2                 N             N              ?              ?
# 3                 N             N              ?              ?
# 4                 N             N              ?              ?
# ...             ...           ...            ...            ...
# 7267              N             N              ?              ?
# 7268              Y             N           5.00              ?
# 7269              N             Y              ?          40.00
# 7270              Y             N          20.00              ?
# 7271              N             N              ?              ?
#
#       CPA_RVN_BEFORE  CPA_RVN_AFTER  ARPU_BEFORE ARPU_AFTER  \
# 0                  ?              ?    26.000000  17.000000
# 1                  ?              ?            ?          ?
# 2                  ?              ?            ?          ?
# 3                  ?              ?            ?          ?
# 4                  ?              ?            ?          ?
# ...              ...            ...          ...        ...
# 7267               ?              ?            ?          ?
# 7268            0.15              ?     8.730000   3.120000
# 7269               ?              ?    29.980000  40.000000
# 7270               ?              ?    17.000000          ?
# 7271               ?              ?            ?          ?
#
#      ACTVIITY_DAYS_AFTER  ACTIVITY_STATUS_AFTER
# 0                      2    DURING & AFTER CAMP
# 1                     37  NO ACTIVITY SINCE SEP
# 2                     38  NO ACTIVITY SINCE SEP
# 3                     37  NO ACTIVITY SINCE SEP
# 4                      5    DURING & AFTER CAMP
# ...                  ...                    ...
# 7267                   0    DURING & AFTER CAMP
# 7268                   0    DURING & AFTER CAMP
# 7269                   0    DURING & AFTER CAMP
# 7270                  36  NO ACTIVITY SINCE SEP
# 7271                   0    DURING & AFTER CAMP
#
# [7272 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['TENURE', 'AGE', 'GENDER', 'NATIONALITY', 'STATE', 'STATUS_BEFORE',
#        'STATUS_AFTER', 'OFFER_TAKER', 'OFFER_TAKE_UP_DT', 'DATA_PURC_BEFORE',
#        'DATA_PURC_AFTER', 'DATA_CHRG_BEFORE', 'DATA_CHRG_AFTER',
#        'DATA_USG_BEFORE', 'DATA_USG_AFTER', 'VOICE_USG_BEFORE',
#        'VOICE_USG_AFTER', 'RLD_IND_BEFORE', 'RLD_IND_AFTER', 'RLD_AMT_BEFORE',
#        'RLD_AMT_AFTER', 'CPA_RVN_BEFORE', 'CPA_RVN_AFTER', 'ARPU_BEFORE',
#        'ARPU_AFTER', 'ACTVIITY_DAYS_AFTER', 'ACTIVITY_STATUS_AFTER'],
#       dtype='object')

# %% [markdown]
# ## Requirements for midterms
# 1. Dataset has enough attributes for star schema drill down and roll up.
# 2. Random values generated for newly added attributes.
# 3. Resulting dataset is 10% of the original dataset, sampled randomly.
#
# ### Existing attributes
# | Variable | Description |
# | --- | --- |
# | ID | Customer ID
# | TENURE | Customer duration with Kation since registration date
# | AGE | Customer age
# | GENDER | Customer gender
# | NATIONALITY | Customer nationality
# | STATE | Customer hometown (state)
# | STATUS_BEFORE | Customer status before campaign launched.
# | STATUS_AFTER | Customer status after campaign ended.
# | OFFER_TAKER | Indicator for customers who opted-in the migration plan.
# | OFFER_TAKE_UP_DT | Date for customers who opted-in the migration plan.
# | DATA_PURC_BEFORE | Indicator for customer who purchased data before campaign launched.
# | DATA_PURC_AFTER | Indicator for customer who purchased data after campaign ended.
# | DATA_CHRG_BEFORE | Total amount of data charged before campaign launched.
# | DATA_CHRG_AFTER | Total amount of data charged after campaign ended.
# | DATA_USG_BEFORE | Data usage before campaign launched.
# | DATA_USG_AFTER | Data usage after campaign ended.
# | VOICE_USG_BEFORE | Voice usage before campaign launched.
# | VOICE_USG_AFTER | Voice usage after campaign ended.
# | RLD_IND_BEFORE | Indicator for customer who reload before campaign launched.
# | RLD_IND_AFTER | Indicator for customer who reload after campaign ended.
# | RLD_AMT_BEFORE | Total of reload amount before campaign launched.
# | RLD_AMT_AFTER | Total of reload amount after campaign ended.
# | ARPU_BEFORE | ARPU before campaign launched.
# | CPA_RVN_BEFORE | Total added value service before campaign launched.
# | CPA_RVN_AFTER | Total added value service after campaign ended.
# | ARPU_AFTER | ARPU after campaign ended.
# | ACTIVITY_DAYS_AFTER | Silent days after campaign ended.
# | ACTIVITY_STATUS_AFTER | Customer activity status after campaign ended.
#
# ### Proposed new attributes
# | Variable | Description |
# | --- | --- |
# | PLAN_ID | Telco plan ID
# | PLAN_TYPE | Type of telco plan
# | VAS_ID | Value added service ID
# | VAS_TYPE | Type of value added service
# | DATE_ID | Original date
# | YEAR | Year
# | QUARTER | Quarter
# | Month | Month
# | DAY | Day
#
# ### Values for new attributes
# Telco Plans
# | PLAN_ID | PLAN_TYPE |
# | --- | --- |
# | 1 | Saver
# | 2 | Premium
#
# Value added services
# | VAS_ID | VAS_TYPE |
# | --- | --- |
# | 1 | Caller_tune
# | 2 | Roaming

# %% [markdown]
# ![Star schema](media/star_schema.jpg)

# %% [markdown]
# ## Create new attributes
#
# New attributes:
# - `PLAN_ID`, `PLAN_TYPE`
# - `VAS_ID`, `VAS_TYPE`
# - `DATE_ID`, `YEAR`, `QUARTER`, `MONTH`, `DAY`

# %% [markdown]
# New attributes `PLAN_ID` and `PLAN_TYPE` will be created and their values are created randomly.

# %%
customer_id = [i for i in range(len(df))]

df["ID"] = customer_id
df
# Out:
#       TENURE  AGE  GENDER NATIONALITY         STATE STATUS_BEFORE  \
# 0        133   33    Male    Malaysia  KLANG VALLEY        Active
# 1         37   41    Male    Malaysia       SARAWAK        Active
# 2         44   21    Male    Malaysia       SARAWAK        Active
# 3        176   69  Female    Malaysia        PENANG        Active
# 4        171   79    Male    Malaysia        JOHORE        Active
# ...      ...  ...     ...         ...           ...           ...
# 7267      28   27    Male    Malaysia  KLANG VALLEY        Active
# 7268      48   25    Male    Malaysia  KLANG VALLEY        Active
# 7269      71   65    Male    Malaysia        PAHANG        Active
# 7270      30   33    Male    Malaysia        JOHORE        Active
# 7271      16   36  Female    Malaysia  KLANG VALLEY        Active
#
#      STATUS_AFTER OFFER_TAKER OFFER_TAKE_UP_DT DATA_PURC_BEFORE  ...  \
# 0          Active           Y        10/6/2022                Y  ...
# 1          Active           Y        10/6/2022                Y  ...
# 2          Active           N                ?                N  ...
# 3          Active           N                ?                N  ...
# 4          Active           Y        10/6/2022                N  ...
# ...           ...         ...              ...              ...  ...
# 7267       Active           Y        10/6/2022                Y  ...
# 7268       Active           Y        10/8/2022                Y  ...
# 7269       Active           Y        10/6/2022                Y  ...
# 7270       Active           N                ?                N  ...
# 7271       Active           Y        10/6/2022                Y  ...
#
#      RLD_IND_AFTER RLD_AMT_BEFORE RLD_AMT_AFTER  CPA_RVN_BEFORE  \
# 0                Y          30.00         30.00               ?
# 1                N              ?             ?               ?
# 2                N              ?             ?               ?
# 3                N              ?             ?               ?
# 4                N              ?             ?               ?
# ...            ...            ...           ...             ...
# 7267             N              ?             ?               ?
# 7268             N           5.00             ?            0.15
# 7269             Y              ?         40.00               ?
# 7270             N          20.00             ?               ?
# 7271             N              ?             ?               ?
#
#       CPA_RVN_AFTER  ARPU_BEFORE  ARPU_AFTER ACTVIITY_DAYS_AFTER  \
# 0                 ?    26.000000   17.000000                   2
# 1                 ?            ?           ?                  37
# 2                 ?            ?           ?                  38
# 3                 ?            ?           ?                  37
# 4                 ?            ?           ?                   5
# ...             ...          ...         ...                 ...
# 7267              ?            ?           ?                   0
# 7268              ?     8.730000    3.120000                   0
# 7269              ?    29.980000   40.000000                   0
# 7270              ?    17.000000           ?                  36
# 7271              ?            ?           ?                   0
#
#       ACTIVITY_STATUS_AFTER    ID
# 0       DURING & AFTER CAMP     0
# 1     NO ACTIVITY SINCE SEP     1
# 2     NO ACTIVITY SINCE SEP     2
# 3     NO ACTIVITY SINCE SEP     3
# 4       DURING & AFTER CAMP     4
# ...                     ...   ...
# 7267    DURING & AFTER CAMP  7267
# 7268    DURING & AFTER CAMP  7268
# 7269    DURING & AFTER CAMP  7269
# 7270  NO ACTIVITY SINCE SEP  7270
# 7271    DURING & AFTER CAMP  7271
#
# [7272 rows x 28 columns]

# %%
import random

plan_id = range(1, 2 + 1)
plan_ids = random.choices(plan_id, k=len(df))
len(plan_ids)
# Out:
# 7272

# %%
df["PLAN_ID"] = plan_ids
df
# Out:
#       TENURE  AGE  GENDER NATIONALITY         STATE STATUS_BEFORE  \
# 0        133   33    Male    Malaysia  KLANG VALLEY        Active
# 1         37   41    Male    Malaysia       SARAWAK        Active
# 2         44   21    Male    Malaysia       SARAWAK        Active
# 3        176   69  Female    Malaysia        PENANG        Active
# 4        171   79    Male    Malaysia        JOHORE        Active
# ...      ...  ...     ...         ...           ...           ...
# 7267      28   27    Male    Malaysia  KLANG VALLEY        Active
# 7268      48   25    Male    Malaysia  KLANG VALLEY        Active
# 7269      71   65    Male    Malaysia        PAHANG        Active
# 7270      30   33    Male    Malaysia        JOHORE        Active
# 7271      16   36  Female    Malaysia  KLANG VALLEY        Active
#
#      STATUS_AFTER OFFER_TAKER OFFER_TAKE_UP_DT DATA_PURC_BEFORE  ...  \
# 0          Active           Y        10/6/2022                Y  ...
# 1          Active           Y        10/6/2022                Y  ...
# 2          Active           N                ?                N  ...
# 3          Active           N                ?                N  ...
# 4          Active           Y        10/6/2022                N  ...
# ...           ...         ...              ...              ...  ...
# 7267       Active           Y        10/6/2022                Y  ...
# 7268       Active           Y        10/8/2022                Y  ...
# 7269       Active           Y        10/6/2022                Y  ...
# 7270       Active           N                ?                N  ...
# 7271       Active           Y        10/6/2022                Y  ...
#
#      RLD_AMT_BEFORE RLD_AMT_AFTER CPA_RVN_BEFORE  CPA_RVN_AFTER  ARPU_BEFORE  \
# 0             30.00         30.00              ?              ?    26.000000
# 1                 ?             ?              ?              ?            ?
# 2                 ?             ?              ?              ?            ?
# 3                 ?             ?              ?              ?            ?
# 4                 ?             ?              ?              ?            ?
# ...             ...           ...            ...            ...          ...
# 7267              ?             ?              ?              ?            ?
# 7268           5.00             ?           0.15              ?     8.730000
# 7269              ?         40.00              ?              ?    29.980000
# 7270          20.00             ?              ?              ?    17.000000
# 7271              ?             ?              ?              ?            ?
#
#       ARPU_AFTER  ACTVIITY_DAYS_AFTER  ACTIVITY_STATUS_AFTER    ID PLAN_ID
# 0      17.000000                    2    DURING & AFTER CAMP     0       2
# 1              ?                   37  NO ACTIVITY SINCE SEP     1       2
# 2              ?                   38  NO ACTIVITY SINCE SEP     2       2
# 3              ?                   37  NO ACTIVITY SINCE SEP     3       1
# 4              ?                    5    DURING & AFTER CAMP     4       2
# ...          ...                  ...                    ...   ...     ...
# 7267           ?                    0    DURING & AFTER CAMP  7267       2
# 7268    3.120000                    0    DURING & AFTER CAMP  7268       2
# 7269   40.000000                    0    DURING & AFTER CAMP  7269       1
# 7270           ?                   36  NO ACTIVITY SINCE SEP  7270       1
# 7271           ?                    0    DURING & AFTER CAMP  7271       1
#
# [7272 rows x 29 columns]

# %%
plans = {1: "Saver", 2: "Premium"}

df["PLAN_TYPE"] = df["PLAN_ID"].apply(lambda x: plans.get(x))
df
# Out:
#       TENURE  AGE  GENDER NATIONALITY         STATE STATUS_BEFORE  \
# 0        133   33    Male    Malaysia  KLANG VALLEY        Active
# 1         37   41    Male    Malaysia       SARAWAK        Active
# 2         44   21    Male    Malaysia       SARAWAK        Active
# 3        176   69  Female    Malaysia        PENANG        Active
# 4        171   79    Male    Malaysia        JOHORE        Active
# ...      ...  ...     ...         ...           ...           ...
# 7267      28   27    Male    Malaysia  KLANG VALLEY        Active
# 7268      48   25    Male    Malaysia  KLANG VALLEY        Active
# 7269      71   65    Male    Malaysia        PAHANG        Active
# 7270      30   33    Male    Malaysia        JOHORE        Active
# 7271      16   36  Female    Malaysia  KLANG VALLEY        Active
#
#      STATUS_AFTER OFFER_TAKER OFFER_TAKE_UP_DT DATA_PURC_BEFORE  ...  \
# 0          Active           Y        10/6/2022                Y  ...
# 1          Active           Y        10/6/2022                Y  ...
# 2          Active           N                ?                N  ...
# 3          Active           N                ?                N  ...
# 4          Active           Y        10/6/2022                N  ...
# ...           ...         ...              ...              ...  ...
# 7267       Active           Y        10/6/2022                Y  ...
# 7268       Active           Y        10/8/2022                Y  ...
# 7269       Active           Y        10/6/2022                Y  ...
# 7270       Active           N                ?                N  ...
# 7271       Active           Y        10/6/2022                Y  ...
#
#      RLD_AMT_AFTER CPA_RVN_BEFORE CPA_RVN_AFTER  ARPU_BEFORE  ARPU_AFTER  \
# 0            30.00              ?             ?    26.000000   17.000000
# 1                ?              ?             ?            ?           ?
# 2                ?              ?             ?            ?           ?
# 3                ?              ?             ?            ?           ?
# 4                ?              ?             ?            ?           ?
# ...            ...            ...           ...          ...         ...
# 7267             ?              ?             ?            ?           ?
# 7268             ?           0.15             ?     8.730000    3.120000
# 7269         40.00              ?             ?    29.980000   40.000000
# 7270             ?              ?             ?    17.000000           ?
# 7271             ?              ?             ?            ?           ?
#
#       ACTVIITY_DAYS_AFTER  ACTIVITY_STATUS_AFTER    ID PLAN_ID PLAN_TYPE
# 0                       2    DURING & AFTER CAMP     0       2   Premium
# 1                      37  NO ACTIVITY SINCE SEP     1       2   Premium
# 2                      38  NO ACTIVITY SINCE SEP     2       2   Premium
# 3                      37  NO ACTIVITY SINCE SEP     3       1     Saver
# 4                       5    DURING & AFTER CAMP     4       2   Premium
# ...                   ...                    ...   ...     ...       ...
# 7267                    0    DURING & AFTER CAMP  7267       2   Premium
# 7268                    0    DURING & AFTER CAMP  7268       2   Premium
# 7269                    0    DURING & AFTER CAMP  7269       1     Saver
# 7270                   36  NO ACTIVITY SINCE SEP  7270       1     Saver
# 7271                    0    DURING & AFTER CAMP  7271       1     Saver
#
# [7272 rows x 30 columns]

# %% [markdown]
# New attributes `VAS_ID` and `VAS_TYPE` will be created and their values are created randomly.

# %%
vas_id = range(1, 2 + 1)
vas_ids = random.choices(vas_id, k=len(df))

df["VAS_ID"] = vas_ids
df
# Out:
#       TENURE  AGE  GENDER NATIONALITY         STATE STATUS_BEFORE  \
# 0        133   33    Male    Malaysia  KLANG VALLEY        Active
# 1         37   41    Male    Malaysia       SARAWAK        Active
# 2         44   21    Male    Malaysia       SARAWAK        Active
# 3        176   69  Female    Malaysia        PENANG        Active
# 4        171   79    Male    Malaysia        JOHORE        Active
# ...      ...  ...     ...         ...           ...           ...
# 7267      28   27    Male    Malaysia  KLANG VALLEY        Active
# 7268      48   25    Male    Malaysia  KLANG VALLEY        Active
# 7269      71   65    Male    Malaysia        PAHANG        Active
# 7270      30   33    Male    Malaysia        JOHORE        Active
# 7271      16   36  Female    Malaysia  KLANG VALLEY        Active
#
#      STATUS_AFTER OFFER_TAKER OFFER_TAKE_UP_DT DATA_PURC_BEFORE  ...  \
# 0          Active           Y        10/6/2022                Y  ...
# 1          Active           Y        10/6/2022                Y  ...
# 2          Active           N                ?                N  ...
# 3          Active           N                ?                N  ...
# 4          Active           Y        10/6/2022                N  ...
# ...           ...         ...              ...              ...  ...
# 7267       Active           Y        10/6/2022                Y  ...
# 7268       Active           Y        10/8/2022                Y  ...
# 7269       Active           Y        10/6/2022                Y  ...
# 7270       Active           N                ?                N  ...
# 7271       Active           Y        10/6/2022                Y  ...
#
#      CPA_RVN_BEFORE CPA_RVN_AFTER ARPU_BEFORE  ARPU_AFTER  \
# 0                 ?             ?   26.000000   17.000000
# 1                 ?             ?           ?           ?
# 2                 ?             ?           ?           ?
# 3                 ?             ?           ?           ?
# 4                 ?             ?           ?           ?
# ...             ...           ...         ...         ...
# 7267              ?             ?           ?           ?
# 7268           0.15             ?    8.730000    3.120000
# 7269              ?             ?   29.980000   40.000000
# 7270              ?             ?   17.000000           ?
# 7271              ?             ?           ?           ?
#
#       ACTVIITY_DAYS_AFTER  ACTIVITY_STATUS_AFTER    ID PLAN_ID PLAN_TYPE  \
# 0                       2    DURING & AFTER CAMP     0       2   Premium
# 1                      37  NO ACTIVITY SINCE SEP     1       2   Premium
# 2                      38  NO ACTIVITY SINCE SEP     2       2   Premium
# 3                      37  NO ACTIVITY SINCE SEP     3       1     Saver
# 4                       5    DURING & AFTER CAMP     4       2   Premium
# ...                   ...                    ...   ...     ...       ...
# 7267                    0    DURING & AFTER CAMP  7267       2   Premium
# 7268                    0    DURING & AFTER CAMP  7268       2   Premium
# 7269                    0    DURING & AFTER CAMP  7269       1     Saver
# 7270                   36  NO ACTIVITY SINCE SEP  7270       1     Saver
# 7271                    0    DURING & AFTER CAMP  7271       1     Saver
#
#      VAS_ID
# 0         2
# 1         2
# 2         1
# 3         2
# 4         2
# ...     ...
# 7267      1
# 7268      2
# 7269      2
# 7270      1
# 7271      1
#
# [7272 rows x 31 columns]

# %%
vas = {1: "Caller_tune", 2: "Roaming"}

df["VAS_TYPE"] = df["VAS_ID"].apply(lambda x: vas.get(x))
df
# Out:
#       TENURE  AGE  GENDER NATIONALITY         STATE STATUS_BEFORE  \
# 0        133   33    Male    Malaysia  KLANG VALLEY        Active
# 1         37   41    Male    Malaysia       SARAWAK        Active
# 2         44   21    Male    Malaysia       SARAWAK        Active
# 3        176   69  Female    Malaysia        PENANG        Active
# 4        171   79    Male    Malaysia        JOHORE        Active
# ...      ...  ...     ...         ...           ...           ...
# 7267      28   27    Male    Malaysia  KLANG VALLEY        Active
# 7268      48   25    Male    Malaysia  KLANG VALLEY        Active
# 7269      71   65    Male    Malaysia        PAHANG        Active
# 7270      30   33    Male    Malaysia        JOHORE        Active
# 7271      16   36  Female    Malaysia  KLANG VALLEY        Active
#
#      STATUS_AFTER OFFER_TAKER OFFER_TAKE_UP_DT DATA_PURC_BEFORE  ...  \
# 0          Active           Y        10/6/2022                Y  ...
# 1          Active           Y        10/6/2022                Y  ...
# 2          Active           N                ?                N  ...
# 3          Active           N                ?                N  ...
# 4          Active           Y        10/6/2022                N  ...
# ...           ...         ...              ...              ...  ...
# 7267       Active           Y        10/6/2022                Y  ...
# 7268       Active           Y        10/8/2022                Y  ...
# 7269       Active           Y        10/6/2022                Y  ...
# 7270       Active           N                ?                N  ...
# 7271       Active           Y        10/6/2022                Y  ...
#
#      CPA_RVN_AFTER ARPU_BEFORE ARPU_AFTER  ACTVIITY_DAYS_AFTER  \
# 0                ?   26.000000  17.000000                    2
# 1                ?           ?          ?                   37
# 2                ?           ?          ?                   38
# 3                ?           ?          ?                   37
# 4                ?           ?          ?                    5
# ...            ...         ...        ...                  ...
# 7267             ?           ?          ?                    0
# 7268             ?    8.730000   3.120000                    0
# 7269             ?   29.980000  40.000000                    0
# 7270             ?   17.000000          ?                   36
# 7271             ?           ?          ?                    0
#
#       ACTIVITY_STATUS_AFTER    ID  PLAN_ID PLAN_TYPE VAS_ID     VAS_TYPE
# 0       DURING & AFTER CAMP     0        2   Premium      2      Roaming
# 1     NO ACTIVITY SINCE SEP     1        2   Premium      2      Roaming
# 2     NO ACTIVITY SINCE SEP     2        2   Premium      1  Caller_tune
# 3     NO ACTIVITY SINCE SEP     3        1     Saver      2      Roaming
# 4       DURING & AFTER CAMP     4        2   Premium      2      Roaming
# ...                     ...   ...      ...       ...    ...          ...
# 7267    DURING & AFTER CAMP  7267        2   Premium      1  Caller_tune
# 7268    DURING & AFTER CAMP  7268        2   Premium      2      Roaming
# 7269    DURING & AFTER CAMP  7269        1     Saver      2      Roaming
# 7270  NO ACTIVITY SINCE SEP  7270        1     Saver      1  Caller_tune
# 7271    DURING & AFTER CAMP  7271        1     Saver      1  Caller_tune
#
# [7272 rows x 32 columns]

# %%
df = df[:round(len(df) * 0.1)]
len(df)
# Out:
# 727

# %% [markdown]
# New attributes `DATE_ID` will be created from `OFFER_TAKE_UP_DT`, while `YEAR`, `QUARTER`, `MONTH` and `DAY` will be created and their values are created randomly.

# %%
df = df[df["OFFER_TAKE_UP_DT"] != "?"]
df = df.reset_index(drop=True)
df
# Out:
#      TENURE  AGE  GENDER NATIONALITY         STATE STATUS_BEFORE STATUS_AFTER  \
# 0       133   33    Male    Malaysia  KLANG VALLEY        Active       Active
# 1        37   41    Male    Malaysia       SARAWAK        Active       Active
# 2       171   79    Male    Malaysia        JOHORE        Active       Active
# 3        38   41    Male    Malaysia       SARAWAK        Active       Active
# 4        37   63    Male    Malaysia         PERAK        Active       Active
# ..      ...  ...     ...         ...           ...           ...          ...
# 446      65   35    Male    Malaysia  KLANG VALLEY        Active       Active
# 447     149   29  Female    Malaysia  KLANG VALLEY        Active       Active
# 448     126   39    Male    Malaysia       SARAWAK        Active       Active
# 449      62   23    Male    Malaysia    TERENGGANU        Active       Active
# 450      29   61    Male    Malaysia       SARAWAK        Active       Active
#
#     OFFER_TAKER OFFER_TAKE_UP_DT DATA_PURC_BEFORE  ... CPA_RVN_AFTER  \
# 0             Y        10/6/2022                Y  ...             ?
# 1             Y        10/6/2022                Y  ...             ?
# 2             Y        10/6/2022                N  ...             ?
# 3             Y        10/6/2022                Y  ...             ?
# 4             Y        10/6/2022                Y  ...             ?
# ..          ...              ...              ...  ...           ...
# 446           Y        10/6/2022                Y  ...             ?
# 447           Y        10/5/2022                Y  ...             ?
# 448           Y        10/6/2022                Y  ...             ?
# 449           Y        10/5/2022                Y  ...             ?
# 450           Y        10/6/2022                Y  ...             ?
#
#     ARPU_BEFORE ARPU_AFTER  ACTVIITY_DAYS_AFTER  ACTIVITY_STATUS_AFTER   ID  \
# 0     26.000000  17.000000                    2    DURING & AFTER CAMP    0
# 1             ?          ?                   37  NO ACTIVITY SINCE SEP    1
# 2             ?          ?                    5    DURING & AFTER CAMP    4
# 3     11.020000   4.200000                    0    DURING & AFTER CAMP    8
# 4     27.990000   1.800000                    1    DURING & AFTER CAMP   11
# ..          ...        ...                  ...                    ...  ...
# 446   39.310000  35.000000                    0    BEFORE & AFTER CAMP  722
# 447           ?          ?                   33  NO ACTIVITY SINCE SEP  723
# 448           ?  10.000000                   34  NO ACTIVITY SINCE SEP  724
# 449    1.450000   0.200000                    0    DURING & AFTER CAMP  725
# 450    3.240000          ?                   36  NO ACTIVITY SINCE SEP  726
#
#      PLAN_ID PLAN_TYPE VAS_ID     VAS_TYPE
# 0          2   Premium      2      Roaming
# 1          2   Premium      2      Roaming
# 2          2   Premium      2      Roaming
# 3          2   Premium      1  Caller_tune
# 4          1     Saver      1  Caller_tune
# ..       ...       ...    ...          ...
# 446        1     Saver      2      Roaming
# 447        1     Saver      1  Caller_tune
# 448        1     Saver      1  Caller_tune
# 449        2   Premium      2      Roaming
# 450        2   Premium      1  Caller_tune
#
# [451 rows x 32 columns]

# %%
df["YEAR"] = df["OFFER_TAKE_UP_DT"].apply(lambda x: x.split("/")[2])
df["MONTH"] = df["OFFER_TAKE_UP_DT"].apply(lambda x: x.split("/")[0])
df["DAY"] = df["OFFER_TAKE_UP_DT"].apply(lambda x: x.split("/")[1])
df
# Out:
#      TENURE  AGE  GENDER NATIONALITY         STATE STATUS_BEFORE STATUS_AFTER  \
# 0       133   33    Male    Malaysia  KLANG VALLEY        Active       Active
# 1        37   41    Male    Malaysia       SARAWAK        Active       Active
# 2       171   79    Male    Malaysia        JOHORE        Active       Active
# 3        38   41    Male    Malaysia       SARAWAK        Active       Active
# 4        37   63    Male    Malaysia         PERAK        Active       Active
# ..      ...  ...     ...         ...           ...           ...          ...
# 446      65   35    Male    Malaysia  KLANG VALLEY        Active       Active
# 447     149   29  Female    Malaysia  KLANG VALLEY        Active       Active
# 448     126   39    Male    Malaysia       SARAWAK        Active       Active
# 449      62   23    Male    Malaysia    TERENGGANU        Active       Active
# 450      29   61    Male    Malaysia       SARAWAK        Active       Active
#
#     OFFER_TAKER OFFER_TAKE_UP_DT DATA_PURC_BEFORE  ... ACTVIITY_DAYS_AFTER  \
# 0             Y        10/6/2022                Y  ...                   2
# 1             Y        10/6/2022                Y  ...                  37
# 2             Y        10/6/2022                N  ...                   5
# 3             Y        10/6/2022                Y  ...                   0
# 4             Y        10/6/2022                Y  ...                   1
# ..          ...              ...              ...  ...                 ...
# 446           Y        10/6/2022                Y  ...                   0
# 447           Y        10/5/2022                Y  ...                  33
# 448           Y        10/6/2022                Y  ...                  34
# 449           Y        10/5/2022                Y  ...                   0
# 450           Y        10/6/2022                Y  ...                  36
#
#      ACTIVITY_STATUS_AFTER   ID  PLAN_ID  PLAN_TYPE  VAS_ID     VAS_TYPE  \
# 0      DURING & AFTER CAMP    0        2    Premium       2      Roaming
# 1    NO ACTIVITY SINCE SEP    1        2    Premium       2      Roaming
# 2      DURING & AFTER CAMP    4        2    Premium       2      Roaming
# 3      DURING & AFTER CAMP    8        2    Premium       1  Caller_tune
# 4      DURING & AFTER CAMP   11        1      Saver       1  Caller_tune
# ..                     ...  ...      ...        ...     ...          ...
# 446    BEFORE & AFTER CAMP  722        1      Saver       2      Roaming
# 447  NO ACTIVITY SINCE SEP  723        1      Saver       1  Caller_tune
# 448  NO ACTIVITY SINCE SEP  724        1      Saver       1  Caller_tune
# 449    DURING & AFTER CAMP  725        2    Premium       2      Roaming
# 450  NO ACTIVITY SINCE SEP  726        2    Premium       1  Caller_tune
#
#      YEAR MONTH DAY
# 0    2022    10   6
# 1    2022    10   6
# 2    2022    10   6
# 3    2022    10   6
# 4    2022    10   6
# ..    ...   ...  ..
# 446  2022    10   6
# 447  2022    10   5
# 448  2022    10   6
# 449  2022    10   5
# 450  2022    10   6
#
# [451 rows x 35 columns]

# %%
df["QUARTER"] = df["MONTH"].apply(lambda x: (int(x)-1)//3 + 1)
df
# Out:
#      TENURE  AGE  GENDER NATIONALITY         STATE STATUS_BEFORE STATUS_AFTER  \
# 0       133   33    Male    Malaysia  KLANG VALLEY        Active       Active
# 1        37   41    Male    Malaysia       SARAWAK        Active       Active
# 2       171   79    Male    Malaysia        JOHORE        Active       Active
# 3        38   41    Male    Malaysia       SARAWAK        Active       Active
# 4        37   63    Male    Malaysia         PERAK        Active       Active
# ..      ...  ...     ...         ...           ...           ...          ...
# 446      65   35    Male    Malaysia  KLANG VALLEY        Active       Active
# 447     149   29  Female    Malaysia  KLANG VALLEY        Active       Active
# 448     126   39    Male    Malaysia       SARAWAK        Active       Active
# 449      62   23    Male    Malaysia    TERENGGANU        Active       Active
# 450      29   61    Male    Malaysia       SARAWAK        Active       Active
#
#     OFFER_TAKER OFFER_TAKE_UP_DT DATA_PURC_BEFORE  ...  ACTIVITY_STATUS_AFTER  \
# 0             Y        10/6/2022                Y  ...    DURING & AFTER CAMP
# 1             Y        10/6/2022                Y  ...  NO ACTIVITY SINCE SEP
# 2             Y        10/6/2022                N  ...    DURING & AFTER CAMP
# 3             Y        10/6/2022                Y  ...    DURING & AFTER CAMP
# 4             Y        10/6/2022                Y  ...    DURING & AFTER CAMP
# ..          ...              ...              ...  ...                    ...
# 446           Y        10/6/2022                Y  ...    BEFORE & AFTER CAMP
# 447           Y        10/5/2022                Y  ...  NO ACTIVITY SINCE SEP
# 448           Y        10/6/2022                Y  ...  NO ACTIVITY SINCE SEP
# 449           Y        10/5/2022                Y  ...    DURING & AFTER CAMP
# 450           Y        10/6/2022                Y  ...  NO ACTIVITY SINCE SEP
#
#       ID PLAN_ID  PLAN_TYPE  VAS_ID     VAS_TYPE  YEAR MONTH DAY QUARTER
# 0      0       2    Premium       2      Roaming  2022    10   6       4
# 1      1       2    Premium       2      Roaming  2022    10   6       4
# 2      4       2    Premium       2      Roaming  2022    10   6       4
# 3      8       2    Premium       1  Caller_tune  2022    10   6       4
# 4     11       1      Saver       1  Caller_tune  2022    10   6       4
# ..   ...     ...        ...     ...          ...   ...   ...  ..     ...
# 446  722       1      Saver       2      Roaming  2022    10   6       4
# 447  723       1      Saver       1  Caller_tune  2022    10   5       4
# 448  724       1      Saver       1  Caller_tune  2022    10   6       4
# 449  725       2    Premium       2      Roaming  2022    10   5       4
# 450  726       2    Premium       1  Caller_tune  2022    10   6       4
#
# [451 rows x 36 columns]

# %%
df = df.rename(columns={"OFFER_TAKE_UP_DT": "DATE_ID"})

# %% [markdown]
# ### Incorrect data

# %%
age_index = random.sample(range(len(df)), round(len(df) * .025))
len(age_index)
# Out:
# 11

# %%
for i in age_index:
    df.loc[i, "AGE"] = 0

df
# Out:
#      TENURE  AGE  GENDER NATIONALITY         STATE STATUS_BEFORE STATUS_AFTER  \
# 0       133   33    Male    Malaysia  KLANG VALLEY        Active       Active
# 1        37   41    Male    Malaysia       SARAWAK        Active       Active
# 2       171   79    Male    Malaysia        JOHORE        Active       Active
# 3        38   41    Male    Malaysia       SARAWAK        Active       Active
# 4        37   63    Male    Malaysia         PERAK        Active       Active
# ..      ...  ...     ...         ...           ...           ...          ...
# 446      65   35    Male    Malaysia  KLANG VALLEY        Active       Active
# 447     149   29  Female    Malaysia  KLANG VALLEY        Active       Active
# 448     126   39    Male    Malaysia       SARAWAK        Active       Active
# 449      62   23    Male    Malaysia    TERENGGANU        Active       Active
# 450      29   61    Male    Malaysia       SARAWAK        Active       Active
#
#     OFFER_TAKER    DATE_ID DATA_PURC_BEFORE  ...  ACTIVITY_STATUS_AFTER   ID  \
# 0             Y  10/6/2022                Y  ...    DURING & AFTER CAMP    0
# 1             Y  10/6/2022                Y  ...  NO ACTIVITY SINCE SEP    1
# 2             Y  10/6/2022                N  ...    DURING & AFTER CAMP    4
# 3             Y  10/6/2022                Y  ...    DURING & AFTER CAMP    8
# 4             Y  10/6/2022                Y  ...    DURING & AFTER CAMP   11
# ..          ...        ...              ...  ...                    ...  ...
# 446           Y  10/6/2022                Y  ...    BEFORE & AFTER CAMP  722
# 447           Y  10/5/2022                Y  ...  NO ACTIVITY SINCE SEP  723
# 448           Y  10/6/2022                Y  ...  NO ACTIVITY SINCE SEP  724
# 449           Y  10/5/2022                Y  ...    DURING & AFTER CAMP  725
# 450           Y  10/6/2022                Y  ...  NO ACTIVITY SINCE SEP  726
#
#     PLAN_ID  PLAN_TYPE  VAS_ID     VAS_TYPE  YEAR MONTH DAY QUARTER
# 0         2    Premium       2      Roaming  2022    10   6       4
# 1         2    Premium       2      Roaming  2022    10   6       4
# 2         2    Premium       2      Roaming  2022    10   6       4
# 3         2    Premium       1  Caller_tune  2022    10   6       4
# 4         1      Saver       1  Caller_tune  2022    10   6       4
# ..      ...        ...     ...          ...   ...   ...  ..     ...
# 446       1      Saver       2      Roaming  2022    10   6       4
# 447       1      Saver       1  Caller_tune  2022    10   5       4
# 448       1      Saver       1  Caller_tune  2022    10   6       4
# 449       2    Premium       2      Roaming  2022    10   5       4
# 450       2    Premium       1  Caller_tune  2022    10   6       4
#
# [451 rows x 36 columns]

# %%
df["AGE"].value_counts()
# Out:
# 29    25
# 24    24
# 26    23
# 23    22
# 22    20
#       ..
# 21     1
# 49     1
# 79     1
# 85     1
# 78     1
# Name: AGE, Length: 61, dtype: int64

# %%
tenure_index = random.sample(range(len(df)), round(len(df) * .025))
len(tenure_index)
# Out:
# 11

# %%
for i in tenure_index:
    df.loc[i, "TENURE"] = 520

df
# Out:
#      TENURE  AGE  GENDER NATIONALITY         STATE STATUS_BEFORE STATUS_AFTER  \
# 0       133   33    Male    Malaysia  KLANG VALLEY        Active       Active
# 1        37   41    Male    Malaysia       SARAWAK        Active       Active
# 2       171   79    Male    Malaysia        JOHORE        Active       Active
# 3        38   41    Male    Malaysia       SARAWAK        Active       Active
# 4        37   63    Male    Malaysia         PERAK        Active       Active
# ..      ...  ...     ...         ...           ...           ...          ...
# 446      65   35    Male    Malaysia  KLANG VALLEY        Active       Active
# 447     149   29  Female    Malaysia  KLANG VALLEY        Active       Active
# 448     126   39    Male    Malaysia       SARAWAK        Active       Active
# 449      62   23    Male    Malaysia    TERENGGANU        Active       Active
# 450      29   61    Male    Malaysia       SARAWAK        Active       Active
#
#     OFFER_TAKER    DATE_ID DATA_PURC_BEFORE  ...  ACTIVITY_STATUS_AFTER   ID  \
# 0             Y  10/6/2022                Y  ...    DURING & AFTER CAMP    0
# 1             Y  10/6/2022                Y  ...  NO ACTIVITY SINCE SEP    1
# 2             Y  10/6/2022                N  ...    DURING & AFTER CAMP    4
# 3             Y  10/6/2022                Y  ...    DURING & AFTER CAMP    8
# 4             Y  10/6/2022                Y  ...    DURING & AFTER CAMP   11
# ..          ...        ...              ...  ...                    ...  ...
# 446           Y  10/6/2022                Y  ...    BEFORE & AFTER CAMP  722
# 447           Y  10/5/2022                Y  ...  NO ACTIVITY SINCE SEP  723
# 448           Y  10/6/2022                Y  ...  NO ACTIVITY SINCE SEP  724
# 449           Y  10/5/2022                Y  ...    DURING & AFTER CAMP  725
# 450           Y  10/6/2022                Y  ...  NO ACTIVITY SINCE SEP  726
#
#     PLAN_ID  PLAN_TYPE  VAS_ID     VAS_TYPE  YEAR MONTH DAY QUARTER
# 0         2    Premium       2      Roaming  2022    10   6       4
# 1         2    Premium       2      Roaming  2022    10   6       4
# 2         2    Premium       2      Roaming  2022    10   6       4
# 3         2    Premium       1  Caller_tune  2022    10   6       4
# 4         1      Saver       1  Caller_tune  2022    10   6       4
# ..      ...        ...     ...          ...   ...   ...  ..     ...
# 446       1      Saver       2      Roaming  2022    10   6       4
# 447       1      Saver       1  Caller_tune  2022    10   5       4
# 448       1      Saver       1  Caller_tune  2022    10   6       4
# 449       2    Premium       2      Roaming  2022    10   5       4
# 450       2    Premium       1  Caller_tune  2022    10   6       4
#
# [451 rows x 36 columns]

# %%
df.to_csv("midterm_dataset.csv", index=False)
